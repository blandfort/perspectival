# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Token-level Differences
#
# We want to visualize for which tokens the models assign different scores.

# %%
import os
from perspectival.model import Transformer, SimpleTransformer

# Set your HuggingFace access token with: `export HUGGINGFACE_TOKEN='your_token_here'`
# (To obtain the access token, see https://huggingface.co/docs/hub/security-tokens)
# Alternatively, simply use other models ;)
model = Transformer('apple/OpenELM-270M', model_kwargs={'trust_remote_code': True},
                    tokenizer_kwargs={'token': os.getenv("HUGGINGFACE_TOKEN")}, lazy_loading=False)
model2 = Transformer('apple/OpenELM-270M-Instruct', model_kwargs={'trust_remote_code': True},
                     tokenizer_kwargs={'token': os.getenv("HUGGINGFACE_TOKEN")}, lazy_loading=False)

# %%
from perspectival.loader import load_anthropic_eval_data, load_hellaswag
from perspectival.experiment import Experiment

dataset, features = load_hellaswag(split='train')
experiment = Experiment(dataset=dataset, name='HellaSwag Test', features=features)

# %%
experiment = experiment.sample(num=100)

# %%
experiment.compute_disagreement(models=[model, model2])
# Out:
# Computing option log likelihoods ...
#   0%|                                                                    | 0/100 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 100%|██████████████████████████████████████████████████████████| 100/100 [00:35<00:00,  2.85it/s]
# Computing option log likelihoods ...
#   0%|                                                                    | 0/100 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 100%|██████████████████████████████████████████████████████████| 100/100 [00:36<00:00,  2.73it/s]

# %%
import numpy as np
from collections import Counter

scores = experiment.get_feature('LogDisagreement', models=(model.name, model2.name)).values
disagreement_rate = sum(scores>0)/len(scores)
print(f"Overall disagreement rate: {disagreement_rate:.2f}\n")

samples = experiment.sample(num=5, sampling_method='last', ordering_scores=scores)
samples.display_items()
# Out:
# Overall disagreement rate: 0.13
#
# ITEM (train_17889)
# """Relationships: How to tell your new boyfriend about your past. Rate your relationship on a scale. Study closely what your relationship is, where it is going, and what you would like it to be in the future. On a scale from 1-10 (1 being bad , 10 being great) rate your relationship at the current moment."""
# Options: ['You can compare your relationship on a scale of one to ten, or you can compare it to how you are in the present. If you are not in a relationship and your partner is not changing, then this is another sign of bad things happening.', "This will help you develop an exact picture of what he's looking for in a relationship. Since an important step towards a successful relationship is to develop your relationship on a scale from 1 to 10, it will take long for him to get the picture.", ' Make sure you and your boyfriend are serious, committed partners. Signs that you are a close, intimate couple include, but are not limited to: shared finances, shared household responsibilities, close sexual intimacy, consistent communication, etc.', "Try to observe how your relationship is almost accepting of your past relationship. For example, if you are currently dating someone and your current boyfriend says he's in an early commitment and you are completely rejected, you might encounter problems in your relationship."]
#
# FEATURES
# GroundTruth 2
# OptionLogLikelihood apple/OpenELM-270M [-109.51822 -121.71273 -123.43568 -148.81258]
# OptionLogLikelihood apple/OpenELM-270M-Instruct [-136.33037 -138.05455 -131.8818  -165.54135]
# LogDisagreement ('apple/OpenELM-270M', 'apple/OpenELM-270M-Instruct') 61.91268
# BinaryDisagreement ('apple/OpenELM-270M', 'apple/OpenELM-270M-Instruct') True
#
#
# --------------------
#
#
# ITEM (train_29851)
# """Holidays and Traditions: How to call lithuania from the united states. Decide what time to place your international call. It will be helpful to pick a time for your phone call that works for both you and the person receiving the call. There is a time difference between lithuania and the united states."""
# Options: ['During most of the year, midnight in lithuania will occur at 5 pm eastern standard time and 2 pm pacific standard time. If in doubt, and you are calling lithuania after midday, place your call an hour earlier.', 'In lithuania, dialing " 6-8-8-0778 " would be nearly impossible. In other countries, you can dial " 00-6-8-0778, " which stands for united states time.', ' You might want to call from the united states if the person who will be calling cannot speak english. The central policy in lithuania is to get up first at 02590 international time.', 'As with any country, regardless of whether you live or work in europe, lithuania is not a " landline " country. You will not be able to call lithuania from another country, even if you have access to a landline.']
#
# FEATURES
# GroundTruth 0
# OptionLogLikelihood apple/OpenELM-270M [-113.13166 -133.29208 -128.99127 -108.0672 ]
# OptionLogLikelihood apple/OpenELM-270M-Instruct [-120.29661 -164.93031 -147.91214 -127.23909]
# LogDisagreement ('apple/OpenELM-270M', 'apple/OpenELM-270M-Instruct') 35.159927
# BinaryDisagreement ('apple/OpenELM-270M', 'apple/OpenELM-270M-Instruct') True
#
#
# --------------------
#
#
# ITEM (train_24470)
# """Health: How to diagnose sore throat causes. Notice if you feel pain or a scratchy sensation. Perhaps one of the key symptoms of a sore throat is a scratchy sensation, like you have an itch in your throat that you cannot reach. You may also feel pain, such as a burning or irritated sensation in your throat."""
# Options: [' Fever and chills are the most common: fever with the body getting rid of the blood and parts that have produce energy. However, fever can also cause headaches or swelling, especially before an injection.', ' You can also develop a flu-like rash if your sore throat does not go away on its own. However, with all of these conditions, coughing and fatigue are the most common causes, so you will want to take action and seek medical attention right away.', " Examine whether you feel irritable. If you happen to have a sore throat the symptom isn't as common.", ' This scratchy sensation may feel worse when you swallow or speak. You may find it difficult to swallow food or speak to someone due to the scratchy or painful sensation in your throat.']
#
# FEATURES
# GroundTruth 3
# OptionLogLikelihood apple/OpenELM-270M [-153.54922 -114.11827  -67.9445   -69.83515]
# OptionLogLikelihood apple/OpenELM-270M-Instruct [-194.23001  -128.13571   -84.652565  -73.69946 ]
# LogDisagreement ('apple/OpenELM-270M', 'apple/OpenELM-270M-Instruct') 20.70846
# BinaryDisagreement ('apple/OpenELM-270M', 'apple/OpenELM-270M-Instruct') True
#
#
# --------------------
#
#
# ITEM (train_28819)
# """Computers and Electronics: How to send an art portfolio by email. Research galleries in the area where you want to sell your work. If possible send a personal note or a postcard with images to introduce yourself. Let them know you are interested in submitting your art for consideration and you want to do so properly."""
# Options: ["Send a subscript email to the people you will be working with in their galleries and ask them for their contact information. This is helpful in the planning of your portfolio because you don't have to worry about typos when submitting it for art exhibitions or drawing collection opportunities.", ' Artist-memorable art reminders are highly important, especially if you are marketing your work on social media websites. Display photographs, your drawings, clips, music, sketches, maps and interviews in a portfolio or sketchbook.', ' You can check in art listings on-line or local guides to determine what type of art they specialize in. Can you see your work fitting in with the style of their gallery? Read what their policies are on submissions, contracts, fees, publicity, art openings/closing receptions, insurance and collecting taxes.', ' Research galleries and art venues that buy and reserve art. You may ask, " hey, i wanted to know if any museums, galleries, and outdoor special art galleries have social gallery classes.']
#
# FEATURES
# GroundTruth 2
# OptionLogLikelihood apple/OpenELM-270M [-170.56128 -167.03165 -221.25526 -165.91568]
# OptionLogLikelihood apple/OpenELM-270M-Instruct [-196.02977 -188.04826 -251.50844 -205.68399]
# LogDisagreement ('apple/OpenELM-270M', 'apple/OpenELM-270M-Instruct') 19.680885
# BinaryDisagreement ('apple/OpenELM-270M', 'apple/OpenELM-270M-Instruct') True
#
#
# --------------------
#
#
# ITEM (train_37917)
# """Food and Entertaining: How to get rid of weevils (flour bugs ). Find the source of the weevils. Although pantry pests can fly, they usually like to stay near their food source. If you've noticed small reddish brown beetles, weevils, in your flour, they may also be in other foods in your pantry."""
# Options: ['The best time to find them is when you want to have a ridiculous feast. If you see the beetles in your pantry, they likely have a group, which means they love to eat everything in your pantry.', 'The easiest way to get rid of adult weevils is to identify the source and create a hive. This may be on a pantry cover, if your pantry is not already constructed, or a shelf, if you need something to grow your crops.', "You should also check for weevils near your pet's food dishes since this may be their source of food. Check for weevils in : Cereals and grains (oats, rice, quinoa, bran).", 'Decrease the frequency of the bugs by submerging them in a small tupperware container of water. The beetles can crawl to the water and drown, so use water containers that catch and trap as many beetles as possible and keep them out of your pantry.']
#
# FEATURES
# GroundTruth 2
# OptionLogLikelihood apple/OpenELM-270M [-108.59653 -144.32703 -111.41246 -135.84897]
# OptionLogLikelihood apple/OpenELM-270M-Instruct [-129.54256 -161.71109 -125.42069 -162.39963]
# LogDisagreement ('apple/OpenELM-270M', 'apple/OpenELM-270M-Instruct') 11.6068945
# BinaryDisagreement ('apple/OpenELM-270M', 'apple/OpenELM-270M-Instruct') True
#
#
# --------------------

# %%
from perspectival.inspect import inspect_texts

# Now we select an item
item = samples.dataset.items[0]

# Display the log diffs for all tokens, including the prompt
texts = [item.prompt + (' ' if not item.prompt.endswith(' ') and not option.startswith(' ') else '') + option
         for option in item.options]

inspect_texts(texts=texts, models=[model, model2])
# Out:
# <div><p>&lt;s&gt;<span style='background-color: #f1f7fd; cursor: pointer;' onmouseover="this.parentNode.parentNode.nextSibling.innerHTML='Difference for actual token (Hol): 0.1185 (apple/OpenELM-270M: -8.5684, apple/OpenELM-270M-Instruct: -8.4499)&lt;br /&gt;apple/OpenELM-270M Top-5:  (-2.73), The (-3.12), I (-3.17), A (-4.01), This (-4.40)&lt;br /&gt;apple/OpenELM-270M-Instruct Top-5:  (-2.75), The (-3.09), I (-3.40), A (-3.96), This (-4.33)';" onmouseout="this.parentNode.parentNode.nextSibling.innerHTML='Hover over a token for details.';">Hol </span><span style='background-color: #d2e3f3; cursor: pointer;' onmouseover="this.parentNode.parentNode.nextSibling.innerHTML='Difference for actual token (id): 0.6987 (apple/OpenELM-270M: -2.4972, apple/OpenELM-270M-Instruct: -1.7985)&lt;br /&gt;apple/OpenELM-270M Top-5: iday (-0.52), id (-2.50), ly (-2.53), istic (-2.77), mes (-3.97)&lt;br /&gt;apple/OpenELM-270M-Instruct Top-5: iday (-1.11), istic (-1.67), id (-1.80), ly (-2.18), mes (-3.70)';" onmouseout="this.parentNode.parentNode.nextSibling.innerHTML='Hover over a token for details.';">id </span><span style='background-color: #f7fbff; cursor: pointer;' onmouseover="this.parentNode.parentNode.nextSibling.innerHTML='Difference for actual token (ays): 0.0015 (apple/OpenELM-270M: -0.0129, apple/OpenELM-270M-Instruct: -0.0114)&lt;br /&gt;apple/OpenELM-270M Top-5: ays (-0.01), aze (-5.03), ay (-6.79), az (-7.99), y (-8.57)&lt;br /&gt;apple/OpenELM-270M-Instruct Top-5: ays (-0.01), aze (-4.84), ay (-7.91), az (-8.46), azz (-8.80)';" onmouseout="this.parentNode.parentNode.nextSibling.innerHTML='Hover over a token for details.';">ays </span><span style='background-color: #edf4fc; cursor: pointer;' onmouseover="this.parentNode.parentNode.nextSibling.innerHTML='Difference for actual token (and): 0.1880 (apple/OpenELM-270M: -2.8510, apple/OpenELM-270M-Instruct: -2.6630)&lt;br /&gt;apple/OpenELM-270M Top-5: are (-1.48), in (-2.02), NEWLINE (-2.74), and (-2.85), , (-3.13)&lt;br /&gt;apple/OpenELM-270M-Instruct Top-5: are (-1.81), in (-1.89), and (-2.66), , (-2.67), NEWLINE (-2.68)';" onmouseout="this.parentNode.parentNode.nextSibling.innerHTML='Hover over a token for details.';">and </span><span style='background-color: #f2f8fd; cursor: pointer;' onmouseover="this.parentNode.parentNode.nextSibling.innerHTML='Difference for actual token (Trad): 0.0938 (apple/OpenELM-270M: -8.3134, apple/OpenELM-270M-Instruct: -8.4072)&lt;br /&gt;apple/OpenELM-270M Top-5: vac (-2.47), travel (-3.15), family (-3.68), the (-3.78), Tra (-3.86)&lt;br /&gt;apple/OpenELM-270M-Instruct Top-5: vac (-2.51), travel (-2.74), family (-3.02), Tra (-3.78), festiv (-3.89)';" onmouseout="this.parentNode.parentNode.nextSibling.innerHTML='Hover over a token for details.';">Trad </span><span style='background-color: #f6faff; cursor: pointer;' onmouseover="this.parentNode.parentNode.nextSibling.innerHTML='Difference for actual token (itions): 0.0214 (apple/OpenELM-270M: -0.0488, apple/OpenELM-270M-Instruct: -0.0274)&lt;br /&gt;apple/OpenELM-270M Top-5: itions (-0.05), ition (-3.77), itional (-3.89), ings (-7.55), it (-7.66)&lt;br /&gt;apple/OpenELM-270M-Instruct Top-5: itions (-0.03), ition (-3.93), itional (-5.05), it (-8.86), itionally (-9.01)';" onmouseout="this.parentNode.parentNode.nextSibling.innerHTML='Hover over a token for details.';">itions </span><span style='background-color: #cddff1; cursor: pointer;' onmouseover="this.parentNode.parentNode.nextSibling.innerHTML='Difference for actual token (:): 0.7931 (apple/OpenELM-270M: -2.8982, apple/OpenELM-270M-Instruct: -2.1051)&lt;br /&gt;apple/OpenELM-270M Top-5: NEWLINE (-0.85), in (-1.86), : (-2.90), of (-3.58), are (-4.04)&lt;br /&gt;apple/OpenELM-270M-Instruct Top-5: NEWLINE (-0.91), in (-1.70), : (-2.11), at (-3.79), Ar (-4.02)';" onmouseout="this.parentNode.parentNode.nextSibling.innerHTML='Hover over a token for details.';">: </span><span style='background-color: #eef5fc; cursor: pointer;' onmouseover="this.parentNode. ...
